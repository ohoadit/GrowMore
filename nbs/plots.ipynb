# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import linregress
import plotly.express as px
import plotly.graph_objects as go
import datetime as dt

from plotly.subplots import make_subplots

import tensorflow as tf

import keras

import h5py

# %%
df = pd.read_csv('./../dataset/MorganStanley.csv')

# %%
df
# Out:
#            Company        Date        Open        High        Low       Close  \
# 0    MorganStanley  2019-11-13   48.520000   48.580002  48.189999   48.389999
# 1    MorganStanley  2019-11-14   48.320000   48.720001  48.209999   48.610001
# 2    MorganStanley  2019-11-15   48.869999   49.160000  48.720001   48.990002
# 3    MorganStanley  2019-11-18   48.840000   49.090000  48.560001   49.029999
# 4    MorganStanley  2019-11-19   49.220001   49.599998  49.209999   49.330002
# ..             ...         ...         ...         ...        ...         ...
# 500  MorganStanley  2021-11-08  100.459999  101.800003  99.970001  100.070000
# 501  MorganStanley  2021-11-09   99.459999  100.309998  98.279999   99.709999
# 502  MorganStanley  2021-11-10   98.739998   99.620003  97.720001   97.769997
# 503  MorganStanley  2021-11-11   98.040001   99.309998  97.470001   98.879997
# 504  MorganStanley  2021-11-12   99.209999   99.889999  98.050003   99.849998
#
#       Adj Close   Volume
# ...

# %%
fig = make_subplots(rows=1, cols=2)

fig  =  px.line(df, x="Date", y="Close")



  
# #         fig.add_trace(go.Scatter(x=support['Date'], y=support['Close'], mode='markers', name='support' , ))
# fig.add_trace(go.Scatter(x=df['Date'], y=df['Close'], mode='markers', name='support_new' , ))


# #         fig.add_trace(go.Scatter(x=resistance['Date'], y=resistance['Close'], mode='markers', name='resistance'))
# fig.add_trace(go.Scatter(x=df['Date'], y=df['Close'], mode='markers', name='resistance_new'))

fig.show()
# Out:
# <div>                            <div id="afe0f4ca-bd4a-4a31-86e7-d3e234ea65cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afe0f4ca-bd4a-4a31-86e7-d3e234ea65cd")) {                    Plotly.newPlot(                        "afe0f4ca-bd4a-4a31-86e7-d3e234ea65cd",                        [{"hovertemplate":"Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2019-11-13","2019-11-14","2019-11-15","2019-11-18","2019-11-19","2019-11-20","2019-11-21","2019-11-22","2019-11-25","2019-11-26","2019-11-27","2019-11-29","2019-12-02","2019-12-03","2019-12-04","2019-12-05","2019-12-06","2019-12-09","20
# ...

# %%
# def root_mean_squared_error(y_true, y_pred):
#     return K.sqrt(K.mean(K.square(y_pred - y_true)))

# from keras.utils.generic_utils import get_custom_objects

# get_custom_objects().update({'my_custom_func': root_mean_squared_error})

# model = keras.models.load_model('./../models/model_morganStanley.h5')
